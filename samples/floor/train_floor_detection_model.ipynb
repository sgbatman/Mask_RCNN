# %% [markdown]
# # Setup training files
#
# 1. Mount google drive with the codes to train the model.
# 2. Run the setup file

# %%
from google.colab import drive
drive.mount('/content/drive/My Drive/Floor_Detection/Mask_RCNN')
# !python setup.py install

# %% [markdown]
# # Train
#
# 1. CD into the dir with the modified python codes
# 2. Run the python file to train the model

# %%
# %cd /content/drive/My Drive/Floor_Detection/Mask_RCNN-master/samples/floor
# !python floor.py train --dataset="/content/drive/My Drive/Floor_Detection_Test/data" --weights=coco
